# %%
import os
from PIL import Image
import time
import pandas as pd

# %%
data_root = '.\\..\\data_raw'

# %% [markdown]
# # STATS

# %%
class_paths = [f.path for f in os.scandir(data_root) if f.is_dir()]

# %%
for c in class_paths:
    subcategory_paths = [f.path for f in os.scandir(c) if f.is_dir()]
    subcategories = [os.path.basename(os.path.normpath(x)) for x in subcategory_paths]
    print(subcategories)
# Out:
# ['amazon', 'games', 'maps', 'news', 'other', 'pinterest', 'reddit', 'shopping', 'twitter', 'youtube']
# ['Art', 'Astronomy', 'Biology', 'Chemistry', 'Data Analytics', 'DrugBiology', 'Genetics', 'IntroductionToEthics', 'IntroductionToPsychology', 'IntroGenderSexuality', 'Literature', 'Management', 'other', 'Philosophy', 'Politics', 'Principles&Practice', 'ProfessionalPractices', 'QuantitativeAnalysis', 'ReadingFilm', 'Social Politics', 'VRdevelopment']

# %%
d = []
for c in class_paths:
    cat = os.path.basename(os.path.normpath(c))
    subcategory_paths = [f.path for f in os.scandir(c) if f.is_dir()]
    for subc in subcategory_paths:
        subcat = os.path.basename(os.path.normpath(subc))
        division_paths = [f.path for f in os.scandir(subc) if f.is_dir()]
        for div in division_paths:
            division = os.path.basename(os.path.normpath(div))
            _, _, files = next(os.walk(div))
            d.append({"class": cat, "subcategory":subcat, "window":division, "samples":len(files)})

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#          class      subcategory   window  samples
# 0   distracted           amazon      one      104
# 1   distracted           amazon  partial        0
# 2   distracted            games      one      159
# 3   distracted            games  partial      184
# 4   distracted             maps      one       15
# ..         ...              ...      ...      ...
# 56     focused      ReadingFilm      one       16
# 57     focused      ReadingFilm  partial        0
# 58     focused  Social Politics      one      161
# 59     focused  Social Politics  partial        0
# 60     focused    VRdevelopment      one       65
#
# [61 rows x 4 columns]

# %%
df.groupby(['window']).sum()
# Out:
#          samples
# window
# one         2654
# partial     1598

# %%
df.groupby(['class']).sum()
# Out:
#             samples
# class
# distracted     1652
# focused        2600

# %%
df.groupby(['class', 'subcategory']).sum()
# Out:
#                                      samples
# class      subcategory
# distracted amazon                        104
#            games                         343
#            maps                           29
#            news                          119
#            other                         245
#            pinterest                     101
#            reddit                        117
#            shopping                      210
#            twitter                        67
#            youtube                       317
# focused    Art                            95
#            Astronomy                     150
#            Biology                       139
#            Chemistry                     157
#            Data Analytics                145
#            DrugBiology                   112
#            Genetics                      125
#            IntroGenderSexuality           65
#            IntroductionToEthics           60
#            IntroductionToPsychology       43
#            Literature                    223
#            Management                    349
#            Philosophy                    144
#            Politics                       11
#            Principles&Practice            83
#            ProfessionalPractices         187
#            QuantitativeAnalysis          151
#            ReadingFilm                    16
#            Social Politics               161
#            VRdevelopment                  65
#            other                         119

# %% [markdown]
# # Creating new clean folder

# %%
clean_root = '.\\..\\datasets\\data_clean_extended'

# %%
counter = dict()
for c in class_paths:
    cat = os.path.basename(os.path.normpath(c))
    counter[cat] = 0
    os.makedirs(os.path.join(clean_root, cat))
    subcategory_paths = [f.path for f in os.scandir(c) if f.is_dir()]
    for subc in subcategory_paths:
        subcat = os.path.basename(os.path.normpath(subc))
        division_paths = [f.path for f in os.scandir(subc) if f.is_dir()]
        for div in division_paths:
            division = os.path.basename(os.path.normpath(div))
            _, _, files = next(os.walk(div))
            for file in files:
                im = Image.open(os.path.join(div, file))
                filemame = cat + '_' + subcat + '_' + division + '_' + str(counter[cat]) + '.jpg'
                if 'png' in file:
                    im = im.convert('RGB')
                im.save(os.path.join(clean_root, cat, filemame))
                counter[cat] += 1
